# %% [markdown]
# # Assignment1B-I

# %% [markdown]
# # Installing and Setting up the Virtual Environment

# %%
import numpy as np

# %% [markdown]
# # Question 1:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = np.array([[163, 170, 166, 168, 155, 172, 182, 150, 149, 168, 159, 151, 169, 157, 170],[94,   71,  49,  59,  63,  64,  58,  47,  50,  85,  72,  57,  88,  56,  77]])

# %%
data
# Out:
# array([[163, 170, 166, 168, 155, 172, 182, 150, 149, 168, 159, 151, 169,
#         157, 170],
#        [ 94,  71,  49,  59,  63,  64,  58,  47,  50,  85,  72,  57,  88,
#          56,  77]])

# %%
np.shape(data)
# Out:
# (2, 15)

# %%
data[1][0]
# Out:
# 94

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
weight = data[1]
height = data[0]

# %%
bmi = weight * 10000 / height**2

# %% [markdown]
# $BMI = \frac{weight}{height^2} \times 10000 $

# %%
print("This is the BMI result:")
print(bmi)
print(f"\nthe type of this data is: {type(bmi)}")
# Out:
# This is the BMI result:
# [35.3795777  24.56747405 17.78197126 20.90419501 26.2226847  21.63331531
#  17.50996256 20.88888889 22.52150804 30.11621315 28.47988608 24.99890356
#  30.8112461  22.7189744  26.64359862]
#
# the type of this data is: <class 'numpy.ndarray'>
