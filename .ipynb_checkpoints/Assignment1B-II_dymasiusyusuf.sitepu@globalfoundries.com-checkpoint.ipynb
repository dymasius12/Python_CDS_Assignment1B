# %% [markdown]
# # Assignment1B-II

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # importing library

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
! pip install seaborn

# %%
import seaborn as sns

# %% [markdown]
# # Question 1:

# %%
df = pd.read_csv('Churn_Analysis.csv')

# %%
df
# Out:
#       Customer_id International plan  Total day minutes  Total day calls  \
# 0               1                 No              265.1              110
# 1               2                 No              161.6              123
# 2               3                 No              243.4              114
# 3               4                Yes              299.4               71
# 4               5                Yes              166.7              113
# ...           ...                ...                ...              ...
# 1996         1997                 No              179.7              128
# 1997         1998                 No              266.0              120
# 1998         1999                 No               96.7               97
# 1999         2000                 No               82.7              116
# 2000         2001                 No              168.2               87
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.describe()
# Out:
#        Customer_id  Total day minutes  Total day calls  Total day charge  \
# count  2001.000000        2001.000000      2001.000000       2001.000000
# mean   1001.000000         180.112994       100.480760         30.619765
# std     577.783264          53.688319        19.983737          9.126995
# min       1.000000           0.000000         0.000000          0.000000
# 25%     501.000000         145.500000        87.000000         24.740000
# 50%    1001.000000         179.900000       101.000000         30.580000
# 75%    1501.000000         216.400000       114.000000         36.790000
# max    2001.000000         350.800000       165.000000         59.640000
#
#        Total eve minutes  Total eve calls  Total eve charge  \
# count        2001.000000      2001.000000       2001.000000
# mean          200.202599       100.134933         17.017426
# std            51.255842        19.963611          4.356717
# min            31.200000        12.000000          2.650000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_id             2001 non-null   int64
#  1   International plan      2001 non-null   object
#  2   Total day minutes       2001 non-null   float64
#  3   Total day calls         2001 non-null   int64
#  4   Total day charge        2001 non-null   float64
#  5   Total eve minutes       2001 non-null   float64
#  6   Total eve calls         2001 non-null   int64
#  7   Total eve charge        2001 non-null   float64
#  8   Total night minutes     2001 non-null   float64
#  9   Total night calls       2001 non-null   int64
#  10  Total night charge      2001 non-null   float64
#  11  Total intl minutes      2001 non-null   float64
#  12  Total intl calls        2001 non-null   int64
#  13  Total intl charge       2001 non-null   float64
# ...

# %%
#this just check if there is null value inside our dataframe!
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Question 2: Print datashape

# %%
print(df.shape)
# Out:
# (2001, 16)

# %% [markdown]
# # Question 3: print the data type of each column. If any column is of datatype Boolean, then convert it to 'int64' datatype and write back to same dataframe.

# %%
#printing the datatypes of each column:
df.dtypes
# Out:
# Customer_id                 int64
# International plan         object
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Attrition                    bool
# dtype: object

# %%
df = df.astype({"Attrition": int64}, errors='raise')

# %%
#encountered int64 not defined. 
from numpy import int64

df['Attrition'] = df['Attrition'].astype(int64)
df.dtypes
# Out:
# Customer_id                 int64
# International plan         object
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Attrition                   int64
# dtype: object

# %%
df['Attrition']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# Name: Attrition, Length: 2001, dtype: int64
